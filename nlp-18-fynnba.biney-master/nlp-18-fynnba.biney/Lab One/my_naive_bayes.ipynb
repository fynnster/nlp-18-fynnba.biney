# %% [markdown]
# # NAIVE BAYES CLASSIFIER

# %% [markdown]
# These are the libraries used in the classifier.

# %%
import random
import re
from math import *

# %%
def merge_files():
    filenames = ["imdb_labelled.txt", "amazon_cells_labelled.txt", "yelp_labelled.txt"]
    with open('newfile.txt', 'w') as outfile:
        for fname in filenames:
            with open(fname) as infile:
                outfile.write(infile.read())

# %% [markdown]
# This block of code reads data from a text file, clean the data from the file and shuffle the sentences in the file.

# %%
def readTXTAndClean():
    file = open("newfile.txt", "r") 
    mass_list=[]

    a_line = file.readlines()
    
    for line in a_line:
        c_line = re.sub(r"[\n\t!';:£*():?%$#+]", "", line.lower())
        mass_list.append(re.sub(r"[\n,.-/]","", c_line))
    

    random.shuffle(mass_list)
    file.close()
    return mass_list

# %% [markdown]
# This function splits the file into testdata and training data

# %%
def split_Data(massList):
    split1= round(len(massList)*.8)
    split2= round(len(massList)*.2)
    
    trainingData= massList[slice(0,split1)]
    testingData= massList[slice(0,split2)]

    return trainingData, testingData

# %% [markdown]
# The sort_List fucntion sorts thadata into two classes, creates a bag of words, counts the totalnumber of sentences and the number of sentences per class.

# %%
def sort_List(trainingData):
    count= 0
    nOfGSent=0
    nOfBSent=0
    goodClass=[]
    badClass=[]
    
    for item in trainingData:
        classOfSentence = trainingData[count][-1]
        theWords = trainingData[count][0:-2].split()
        count = count + 1

        if classOfSentence == '1':
            nOfGSent +=1
            goodClass = goodClass + theWords
        else:
            nOfBSent +=1
            badClass = badClass + theWords
            
    goodClass =sorted(goodClass)
    badClass =sorted(badClass)
    
    goodClassDict = {x:goodClass.count(x) for x in goodClass}
    badClassDict = {x:badClass.count(x) for x in badClass}
    bagOfWords = goodClassDict.copy()
    bagOfWords.update(badClassDict)
    
    #print(bagOfWords)
    

    return goodClassDict, badClassDict, bagOfWords, nOfGSent, nOfBSent, count

# %% [markdown]
# The logprior function calculates the logprior per class using;

# %% [markdown]
# $$\log \frac{N_c}{N_{doc}}$$

# %%
def logPior(noofgoodSent, noofbadSent, noofSent):    
    logpriorGood= log10(noofgoodSent/noofSent)
    logpriorBad= log10(noofbadSent/noofSent)

    print(logpriorGood, logpriorBad)
    return logpriorGood, logpriorBad

# %% [markdown]
# $$\log \frac{count(w,c)+1}{\sum_{w\in v}(count(w′,c)+1)}$$

# %%
def baseloglikelyhood(the_Class,bagOfWords):
    loglikelyhood = 0
    countVocab= len(bagOfWords)
    loglikely= {}
    total_words_per_class= sum(the_Class.values())
#     print(the_Class.values())
    
    denominator = total_words_per_class + countVocab
    
    
    for key, value in bagOfWords.items():
        if key in the_Class.keys():
            count= the_Class[key] + 1
            loglikelyhood = log(count/denominator)
            loglikely[key]= loglikelyhood
            
        else:
            count= 1
            loglikelyhood = log(count/denominator)
            loglikely[key]= loglikelyhood
        
       
    return loglikely

# %%
def x(bagOfWords,the_Class, word):
    if word in the_Class.keys():
        numerator = the_Class[word] +1
    else:
        numerator = 1   
    
    
    denominator= len(set(bagOfWords.keys()) - set(the_Class.keys()))+len(the_Class.keys())
    denominator+= sum(the_Class.values())
    
    log_likelihood =  log(numerator/denominator)
    
    
    
    return log_likelihood

# %% [markdown]
# The loglikelyhood function uses the baseloglikelyhood funtion to calculate the log likelyhood per word.
# It returns two dictionaries, likelyhoodgood, likelyhoodbad using;

# %%
def loglikelyhood(goodDict, badDict, wordBag):
    likelyhoodgood={}
    likelyhoodbad={}
    words=[]
    
 
    likelyhoodgood = baseloglikelyhood(goodDict,wordBag)
    likelyhoodbad = baseloglikelyhood(badDict,wordBag)
    
    return likelyhoodgood, likelyhoodbad

# %%
def test_naive_Bayes(testClass,logprobofGoodwords, logprobofBadwords, logProbGood,logProbBad ):
    
    outcome=[]
    pos= 0
    neg= 0

    for i in range(len(testClass)):
        a_sentence = testClass[i]
        words = testClass[i][0:-1].split()
        
    
        for j in words: 
            if j in logProbGood.keys():
                pos = logprobofGoodwords + logProbGood[j]
                
        for j in words: 
            if j in logProbBad.keys():
                neg = logprobofBadwords + logProbBad[j]
                
        
        with open("results_n_myLogReg.txt", "w+") as file:
        file.write(outcome)
        
        if (pos > neg):
            outcome.append(1)
            print(1, a_sentence)
        elif (pos < neg):
            outcome.append(0)
            print(0, a_sentence)
        
        with open("results.txt", "w+") as file:
            file.write(str(outcome,a_sentence))

        
    return outcome
# Out:
#   File "<ipython-input-23-a0bdd5ceed37>", line 22
#     file.write(outcome)
#        ^
# IndentationError: expected an indented block

# %%
def runAll():
    merge_files()
   
    #this trains the Naive Bayes Classifier
    massList = readTXTAndClean()
    trainingData, testingData = split_Data(massList)
    goodDict, badDict, wordBag, noofgoodSent, noofbadSent, noofSent  = sort_List(trainingData)
    logprobofGoodwords, logprobofBadwords = logPior(noofgoodSent, noofbadSent, noofSent)
    logProbGood,logProbBad = loglikelyhood(goodDict, badDict, wordBag)
    
    

    test_naive_Bayes(testingData,logprobofGoodwords, logprobofBadwords, logProbGood,logProbBad)
    
runAll()
# Out:
# -0.30175442365831345 -0.3003067740448853
# 0 if you want a sandwich just go to any firehouse1
# 1 no complaints1
# 1 crisp and clear1
# 0 it does everything the description said it would1
# 1 when a song could explain the emotions of the subjects better such as when jay adams unfortunate life was a subject of talk the song old man by neil young was played which evokes many emotions  1
# 1 worked very well paired with a treo 700w and as a skype headset on my pc using a usb bluetooth transceiver1
# 0 it makes very strange ticking noises before it ends the call0
# 0 eew this location needs a complete overhaul0
# 0 thoroughly disappointed0
# 0 from what my dinner companions told meeverything was very fresh with nice texture and taste1
# 0 bad purchase0
# 0 also if your phone is dropped this case is not going to save it specially when dropped face down0
# 1 this place deserves no stars0
# 1 clipping this to your belt will deffinitely make you feel like 50 cents up-and-coming1
# 1 the directing and the cinematography arent quite as good  0
# 0 however there was so much garlic in the fondue it was barely edible0
# 0 you learn a lot about the real inside emotions of people in this movie and a lot about the movie business itself  1
# 0 after all the rave reviews i couldnt wait to eat herewhat a disappointment0
# 1 low quality0
# 0 on the ground right next to our table was a large smeared been-stepped-in-and-tracked-everywhere pile of green bird poop0
# 0 but now that it is "out of warranty" the same problems reoccurebottom line put your money somewhere else cingular will not support it0
# 0 the foreigner is not worth one second of your time  0
# 1 it even has its sweet moments  1
# 0 the plot such as it is is so derivative and predictable that the ending is like a mercy killing  0
# 1 very displeased0
# 0 avoid at all costs  0
# 1 putting the race card aside lets look at the major flaw in the film they destroy latifas character  0
# 1 on the good side the staff was genuinely pleasant and enthusiastic - a real treat1
# 1 the mic is great1
# 1 this hole in the wall has great mexican street tacos and friendly staff1
# 1 also the fries are without a doubt the worst fries ive ever had0
# 0 poor quality and service0
# 1 my phone doesnt slide around my car now and the grip prevents my phone from slipping out of my hand1
# 0 this is an unbelievable bargain1
# 1 i did not bother contacting the company for few dollar product but i learned the lesson that i should not have bought this form online anyway0
# 1 the food was very good1
# 0 disappointing0
# 1 the sweet potato fries were very good and seasoned well1
# 0 they dropped more than the ball0
# 1 everything about this product is wrongfirst0
# 0 even billy bob couldnt rise above the script which was worse  0
# 0 having trouble with volume0
# 1 join the club and get awesome offers via email1
# 0 big disappointment with calendar sync0
# 0 this movie was kind of long in length but i enjoyed every minute of it  1
# 0 i saw this movie and i thought this is a stupid movie  0
# 0 i love this phone1
# 1 good case1
# 0 great movie  1
# 0 long whiny and pointless  0
# 0 they will customize your order any way youd like my usual is eggplant with green bean stir fry love it1
# 1 and it was way to expensive0
# 1 their steaks are 100 recommended1
# 1 does not fit0
# 0 headset works great & was packaged nicely to avoid any damage1
# 0 how awesome is that1
# 1 the scripting of the subtle comedy is unmatched by any movie in recent years  1
# 1 i would definitely recommend the wings as well as the pizza1
# 1 its a little geeky but i think thats its sex on toast and it rocks and oozes sex right down to its battery embedded sleek stylish leather case1
# 0 this movie is bad  0
# 0 i work in the hospitality industry in paradise valley and have refrained from recommending cibo any longer0
# 1 i really hope the team behind this movie makes more movies and that they will continue to do so in their own some kinda weird style  1
# 0 pretty piece of junk0
# 1 great product and price1
# 1 the fact is this film is a wonderful heartwarming tale about two people chasing their dreams  1
# 0 protects the phone on all sides1
# 0 woa talk about awful  0
# 1 it is a really good show to watch  1
# 0 a drive thru means you do not want to wait around for half an hour for your food but somehow when we end up going here they make us wait and wait0
# 1 not good when wearing a hat or sunglasses0
# 1 this is some seriously good pizza and im an expertconnisseur on the topic1
# 1 but in terms of the writing its very fresh and bold  1
# 1 i love the pho and the spring rolls oh so yummy you have to try1
# 0 highly recommended for all ages although the younger set will probably not appreciate some of the more subtle references they will certainly appreciate one galley scene in particular  1
# 1 this case has passed the one year mark and while it shows signs of wear it is 100 functional1
# 0 would recommend this item1
# 0 then theres the plot holes  0
# 1 i have been here several times in the past and the experience has always been great1
# 0 i let my girlfriend talk me into seeing this - bad idea we both hated it  0
# 1 on three different occasions i asked for well done or medium well and all three times i got the bloodiest piece of meat on my plate0
# 1 linda cardellini is the only thing good in this film  1
# 0 i have always used corded headsets and the freedom from the wireless is very helpful1
# 0 probably not in a hurry to go back0
# 0 after the first charge kept going dead after 12 minutes0
# 1 it was very popular when i was in the cinema a good house and very good reactions and plenty of laughs  1
# 0 the story is lame not interesting and never really explains the sinister origins of the puppets  0
# 0 i bought this phone as a replacement for my startac and have regretted it since0
# 1 kathy bates is wonderful in her characters subtle desperation and escapism a variation on her character in "at play in the fields of the lord"  1
# 1 and quite honestly often its not very good  0
# 1 by this point my friends and i had basically figured out this place was a joke and didnt mind making it publicly and loudly known0
# 0 the selection was probably the worst ive seen in vegasthere was none0
# 0 the warm beer didnt help0
# 1 it probably would have been better if the director hadnt spent most of the movie showcasing his own art work which really isnt that noteworthy  0
# 1 i loved their mussels cooked in this wine reduction the duck was tender and their potato dishes were delicious1
# 1 we watched our waiter pay a lot more attention to other tables and ignore us0
# 1 real sushi lovers lets be honest - yama is not that good0
# 0 the only thing worse than taylors acting was stanwycks singing  0
# 0 i bought it for my mother and she had a problem with the battery0
# 1 i have had mine for about a year and this christmas i bought some for the rest of the family1
# 0 does not work for listening to music with the cingular 81250
# 1 the chicken wings contained the driest chicken meat i have ever eaten0
# 0 however this didnt make up for the fact that overall this was a tremendously boring movie  0
# 1 it only recognizes the phone as its storage device0
# 0 theres also enough hypocrisy in this film to make me vomit  0
# 1 i have to use the smallest earpieces provided but it stays on pretty well1
# 0 but when someone strives for greatness and poetry but delivers a muddled and often ridiculous story a bunch of disparate scenes pretentious dialogue then you get the worst kind of a movie that some other reviewer very accurately defined as "pretentious crap"  0
# 0 last time buying from you0
# 1 penne vodka excellent1
# 0 the steak and the shrimp are in my opinion the best entrees at gc1
# 0 then i exchanged for the same phone even that had the same problem0
# 1 both do good jobs and are quite amusing  1
# 1 saw the movie today and thought it was a good effort good messages for kids  1
# 0 dont waste your money0
# 0 i have to jiggle the plug to get it to line up right to get decent volume0
# 0 t-mobile has the best customer service anywhere1
# 0 good value great food great service1
# 1 very pleased with this headset1
# 1 like the other reviewer said "you couldnt pay me to eat at this place again"0
# 1 very little music or anything to speak of  0
# 1 its practically perfect in all of them â– a true masterpiece in a sea of faux "masterpieces  1
# 1 it felt like a very gripping intelligent stage play but without the overly theatrical feeling one actually gets from watching people on a stage which plays on everyones terror of a white lie escalating to monstrous consequences  1
# 1 all of the main players are mesmerising  1
# 1 still it makes up for all of this with a super ending that depicts a great sea vessel being taken out by the mighty frost  1
# 0 i went on motorolas website and followed all directions but could not get it to pair again0
# 0 the refried beans that came with my meal were dried out and crusty and the food was bland0
# 1 when my mom and i got home she immediately got sick and she only had a few bites of salad0
# 1 i use this product in a motor control center where there is a lot of high voltage humming from the equipment and it works great1
# 0 go watch it  1
# 0 i wish i could enter negative values admins  0
# 1 bad choice0
# 0 the script is bad very bad â– it contains both cheesiness and unethical joke that you normally see in rated r or nc-17 movie  0
# 0 no one at the table thought the food was above average or worth the wait that we had for it0
# 1 it is rare when a film-maker takes the time to tell a worthy moral tale with care and love that doesnt fall into the trap of being overly syrupy or over indulgent  1
# 1 the performances are not improved by improvisation because the actors now have twice as much to worry about not only whether theyre delivering the line well but whether the line itself is any good  0
# 1 updatewent back for a second time and it was still just as amazing1
# 1 the camera on the phone may be used as a dustpan when indoors id rather be using a disposable then this0
# 1 another note about this phones appearance is that it really looks rather bland especially in the all black model0
# 1 im using it with an iriver spinn with case and it fits fine1
# 1 our waiter was very attentive friendly and informative1
# 1 this was reflected not only in the cast but also in the below-par script which borrowed much from the earlier classic  0
# 0 then our food came out disappointment ensued0
# 1 it has all the features i want1
# 0 his losing his marbles so early in the proceedings is totally implausible and unconvincing  0
# 1 nice headset priced right1
# 1 the voice recognition thru the handset is excellent1
# 1 i hate to disagree with my fellow yelpers but my husband and i were so disappointed with this place0
# 1 there was a warm feeling with the service and i felt like their guest for a special treat1
# 1 this is one of the best italian thrillers of the early 70s  1
# 0 a good time1
# 1 bacon is hella salty1
# 1 the macarons here are insanely good1
# 1 definitely worth venturing off the strip for the pork belly will return next time im in vegas1
# 1 the handsfree part works fine but then the car tries to download the address book and the treo rebootsoverall i still rate this device high1
# 1 this movie is excellentangel is beautiful and scamp is adorablehis little yelps when hes scaredand the funniest parts are whenscamp is caught under the curtain and when angel and scamp are singing ive never had this feeling beforei totally recommend this movieits coming out on special edition on june 20the cover has scamp on a garbage can and angel underneath the lid  1
# 1 excellent sound quality1
# 0 only like 3 or 4 buildings used a couple of locations maybe & poor hummh  0
# 1 his on screen presence shined thought even though there were other senior actors on the screen with him  1
# 1 once you get inside youll be impressed with the place1
# 1  item arrived quickly and works great with my metro pcs samsung sch-r450 slider phone and sony premium sound in ear plugs1
# 0 it didnt charge for me0
# 0 if you hate earbugs avoid this phone by all means0
# 0 the food was terrible0
# 1 i liked the patio and the service was outstanding1
# 0 the first thing that happened was that the tracking was off0
# 0 i was not happy with this item0
# 0 it is shameful  0
# 0 very disappointed and wondered how it could be in the oscar shortlist  0
# 0 initially the local sites in the film which was filmed here in buffalo intrigued me  1
# 1 the greek dressing was very creamy and flavorful1
# 1 this is one of the best bars with food in vegas1
# 0 an hour and a half i wish i could bring back  0
# 1 nothing at all to recommend  0
# 0 my 810 score is mostly for the plot  1
# 1 much less than the jawbone i was going to replace it with1
# 1 things that went wrong - they burned the saganaki0
# 0 the design is very odd as the ear "clip" is not very comfortable at all0
# 1 my sashimi was poor quality being soggy and tasteless0
# 1 this little device has transformed my organizational capability and made my life a whole lot easier1
# 0 theres a horrible tick sound in the background on all my calls that i have never experienced before0
# 1 poor product0
# 1 poor sound quality0
# 0 restaurant is always full but never a wait1
# 0 battery is terrible0
# 0 battery life still not long enough in motorola razor v3i0
# 0 lucy bell is so much higher than this crap and for her to sink this low is quite depressing  0
